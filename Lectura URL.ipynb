# %% [markdown]
# # Leer desde URL, usar paquetes csv y urllib3

# %%
import pandas as pd
medals_url="http://winterolympicsmedals.com/medals.csv"
df_medals=pd.read_csv(medals_url)

# %%
df_medals
# Out:
#       Year      City       Sport       Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT             individual
# 1     1924  Chamonix     Skating   Figure skating  AUT             individual
# 2     1924  Chamonix     Skating   Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN             ice hockey
# 5     1924  Chamonix    Biathlon         Biathlon  FIN        military patrol
# 6     1924  Chamonix     Skating   Figure skating  FIN                  pairs
# 7     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 8     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 9     1924  Chamonix     Skating    Speed skating  FIN                  1500m
# 10    1924  Chamonix     Skating    Speed skating  FIN                  5000m
# ...

# %%
df_medals.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
import csv
import urllib

# %%
response = urllib.response(df_medals)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3bf2e1cf5ed9> in <module>
# ----> 1 response = urllib.response(df_medals)
#
# TypeError: 'module' object is not callable

# %%
response = urllib.urlopen(df_medals)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-cecd81316a3d> in <module>
# ----> 1 response = urllib.urlopen(df_medals)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
import urllib3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-920a64d25c7f> in <module>
# ----> 1 import urllib3
#
# ModuleNotFoundError: No module named 'urllib3'

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"

# %%
http = urllib3.PoolManager()

# %%
r=http.request('GET','http://winterolympicsmedals.com/medals.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
r.data

# %%
r.status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-73d48342b3d9> in <module>
# ----> 1 r.status
#
# NameError: name 'r' is not defined

# %%
r=http.request('GET','http://winterolympicsmedals.com/medals.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
from urllib3 import PoolManager

# %%
http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2d26a2906b2b> in <module>
# ----> 1 http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)
#
# TypeError: urlopen() missing 2 required positional arguments: 'method' and 'url'

# %%
http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)

# %%
import urllib3
medals_url="http://www.betfairpromo.com/betfairsp/prices/dwbfpricesireplace27052019.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data

# %%
import pandas as pd
medals_url="http://www.betfairpromo.com/betfairsp/prices/dwbfpricesireplace27052019.csv"
df= pd.read_csv(medals_url)

# %%
df.head()
# Out:
#     EVENT_ID             MENU_HINT    EVENT_NAME          EVENT_DT  \
# 0  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 1  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 2  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 3  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 4  159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
#
#    SELECTION_ID     SELECTION_NAME  WIN_LOSE        BSP      PPWAP  \
# 0         80666          Teddy Boy         0   3.608550   3.600628
# 1       7586010       Lilys Prince         0   5.800000   6.081712
# 2      18749453          Angelorum         0  29.000000  17.874478
# 3      13132458         Early Call         0  11.089834   9.611303
# 4      16083638  Shakespearsgalley         0   2.800000   2.655395
#
#    MORNINGWAP  PPMAX  PPMIN  IPMAX   IPMIN  MORNINGTRADEDVOL  PPTRADEDVOL  \
# 0    3.707810   3.65   3.50   1.00  1001.0            562.82      3005.34
# ...

# %%
import urllib3

# %%
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...
