# %% [markdown]
# # Leer desde URL, usar paquetes csv y urllib3

# %%
import pandas as pd
medals_url="http://winterolympicsmedals.com/medals.csv"
df_medals=pd.read_csv(medals_url)

# %%
df_medals
# Out:
#       Year      City       Sport       Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT             individual
# 1     1924  Chamonix     Skating   Figure skating  AUT             individual
# 2     1924  Chamonix     Skating   Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN             ice hockey
# 5     1924  Chamonix    Biathlon         Biathlon  FIN        military patrol
# 6     1924  Chamonix     Skating   Figure skating  FIN                  pairs
# 7     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 8     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 9     1924  Chamonix     Skating    Speed skating  FIN                  1500m
# 10    1924  Chamonix     Skating    Speed skating  FIN                  5000m
# ...

# %%
df_medals.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
import csv
import urllib

# %%
response = urllib.response(df_medals)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3bf2e1cf5ed9> in <module>
# ----> 1 response = urllib.response(df_medals)
#
# TypeError: 'module' object is not callable

# %%
response = urllib.urlopen(df_medals)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-cecd81316a3d> in <module>
# ----> 1 response = urllib.urlopen(df_medals)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
import urllib3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-920a64d25c7f> in <module>
# ----> 1 import urllib3
#
# ModuleNotFoundError: No module named 'urllib3'

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"

# %%
http = urllib3.PoolManager()

# %%
r=http.request('GET','http://winterolympicsmedals.com/medals.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
r.data

# %%
r.status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-73d48342b3d9> in <module>
# ----> 1 r.status
#
# NameError: name 'r' is not defined

# %%
r=http.request('GET','http://winterolympicsmedals.com/medals.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
import urllib3
medals_url="http://winterolympicsmedals.com/medals.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
from urllib3 import PoolManager

# %%
http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2d26a2906b2b> in <module>
# ----> 1 http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)
#
# TypeError: urlopen() missing 2 required positional arguments: 'method' and 'url'

# %%
http = urllib3.connectionpool.HTTPSConnectionPool.urlopen(medals_url)

# %%
import urllib3
medals_url="http://www.betfairpromo.com/betfairsp/prices/dwbfpricesireplace27052019.csv"
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
r.data

# %%
import pandas as pd
medals_url="http://www.betfairpromo.com/betfairsp/prices/dwbfpricesireplace27052019.csv"
df= pd.read_csv(medals_url)

# %%
df.head()
# Out:
#     EVENT_ID             MENU_HINT    EVENT_NAME          EVENT_DT  \
# 0  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 1  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 2  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 3  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 4  159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
#
#    SELECTION_ID     SELECTION_NAME  WIN_LOSE        BSP      PPWAP  \
# 0         80666          Teddy Boy         0   3.608550   3.600628
# 1       7586010       Lilys Prince         0   5.800000   6.081712
# 2      18749453          Angelorum         0  29.000000  17.874478
# 3      13132458         Early Call         0  11.089834   9.611303
# 4      16083638  Shakespearsgalley         0   2.800000   2.655395
#
#    MORNINGWAP  PPMAX  PPMIN  IPMAX   IPMIN  MORNINGTRADEDVOL  PPTRADEDVOL  \
# 0    3.707810   3.65   3.50   1.00  1001.0            562.82      3005.34
# ...

# %%
import urllib3

# %%
http = urllib3.PoolManager()
r=http.request('GET',medals_url)
r.status
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
df.head(n=20)
# Out:
#      EVENT_ID             MENU_HINT    EVENT_NAME          EVENT_DT  \
# 0   159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 1   159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 2   159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 3   159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 4   159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
# 5   159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
# 6   159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
# 7   159207956  IRE / Curr  26th May  TO BE PLACED  26-05-2019 17:30
# 8   159207961  IRE / Curr  26th May  TO BE PLACED  26-05-2019 18:00
# 9   159207961  IRE / Curr  26th May  TO BE PLACED  26-05-2019 18:00
# 10  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 11  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# 12  159207931  IRE / Curr  26th May  TO BE PLACED  26-05-2019 14:20
# ...

# %%
import csv

# %%
cr= csv.reader(df)

# %%
cr

# %% [markdown]
# # Leer de un Excel

# %%
df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls" sheet_name="titanic3")
# Out:
#   File "<ipython-input-13-d281f47481f7>", line 1
#     df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls" sheet_name="titanic3")
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls",sheet_name="titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-27634b96d7b7> in <module>
# ----> 1 df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls",sheet_name="titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xlsx",sheet_name="titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-1c893338c9ad> in <module>
# ----> 1 df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xlsx",sheet_name="titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls","titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-4e201868eea3> in <module>
# ----> 1 df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls","titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
# ...

# %%
df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xlsx","titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-cd0c5bcdd7a5> in <module>
# ----> 1 df2=pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xlsx","titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
# ...

# %%
import pandas as pd

# %%
df2 = pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls","titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-28c342269cfb> in <module>
# ----> 1 df2 = pd.read_excel("../python-ml-course/datasets/titanic/titanic3.xls","titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
# ...

# %%
mainpath="/Users/jaldoj/Documents/Developer/python-ml-course/datasets"

# %%
df2 = pd.read_excel(mainpath+"/titanic/titanic3.xls","titanic3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-59dd6bd74459> in <module>
# ----> 1 df2 = pd.read_excel(mainpath+"/titanic/titanic3.xls","titanic3")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
# ...

# %%
df2 = pd.read_excel(mainpath+"/titanic/titanic3.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-ba95c652f1f8> in <module>
# ----> 1 df2 = pd.read_excel(mainpath+"/titanic/titanic3.xls")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
# ...

# %%
df2 = pd.read_excel(mainpath+"/titanic/titanic3.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-6a66f7e3c600> in <module>
# ----> 1 df2 = pd.read_excel(mainpath+"/titanic/titanic3.xlsx")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
# ...

# %%
df4 = pd.read_excel(mainpath+"/titanic/titanic3.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     390         try:
# --> 391             import xlrd
#     392         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-92dac4654619> in <module>
# ----> 1 df4 = pd.read_excel(mainpath+"/titanic/titanic3.xlsx")
#
# ~\AppData\Local\Continuum\anaconda3\envs\cursoML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
# ...

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
mainpath="/Users/jaldoj/Documents/Developer/python-ml-course/datasets"
df5 = pd.read_excel(mainpath+"/titanic/titanic3.xlsx","titanic3")

# %%
df5.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
mainpath="/Users/jaldoj/Documents/Developer/python-ml-course/datasets"
df6 = pd.read_excel(mainpath+"/titanic/titanic3.xls","titanic3")

# %%
df6.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# # Pasar excel a csv

# %%
df6.to_csv(mainpath+"/titanic/titanic3_conver.csv)
# Out:
#   File "<ipython-input-6-cfaaac617149>", line 1
#     df6.to_csv(mainpath+"/titanic/titanic3_conver.csv)
#                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
df6.to_csv(mainpath+"/titanic/titanic3_conver.csv")

# %%
df6.to_json(mainpath+"/titanic/titanic3_conver.json")
